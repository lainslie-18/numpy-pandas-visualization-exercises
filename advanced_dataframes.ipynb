# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Run python -m pip install pymysql from your terminal to install the mysql client (any folder is fine)
# 2. cd into your exercises folder for this module and run echo env.py >> .gitignore
# 3. Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.
# 4. Use your function to obtain a connection to the employees database.

# %%
def get_db_url(db_name):
    from env import user, host, password
    return f'mysql+pymysql://{user}:{password}@{host}/{db_name}'

# %%
sql = """
    SELECT * from employees limit 10
"""

# %%
url = get_db_url("employees")

employees = pd.read_sql(sql, url)
employees.head()
# Out:
#   dept_no  emp_no  birth_date first_name    last_name gender   hire_date  \
# 0    d009   10011  1953-11-07       Mary        Sluis      F  1990-01-22
# 1    d009   10038  1960-07-20       Huan        Lortz      M  1989-09-20
# 2    d009   10049  1961-04-24      Basil       Tramer      F  1992-05-04
# 3    d009   10060  1961-10-15   Breannda  Billingsley      M  1987-11-02
# 4    d009   10088  1954-02-25   Jungsoon     Syrzycki      F  1988-09-02
#
#     from_date     to_date         dept_name
# 0  1990-01-22  1996-11-09  Customer Service
# 1  1989-09-20  9999-01-01  Customer Service
# 2  1992-05-04  9999-01-01  Customer Service
# 3  1992-11-11  9999-01-01  Customer Service
# 4  1992-03-21  9999-01-01  Customer Service

# %% [markdown]
# 5. Once you have successfully run a query:
#
# a. Intentionally make a typo in the database url. What kind of error message do you see?

# %%
# url = get_db_url("employes")

# df = pd.read_sql(sql, url)
# df

# %% [markdown]
# b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
# sql = """
#     SELECT last_name, department from employees limit 3000
# """
# url = get_db_url("employees")

# df = pd.read_sql(sql, url)
# df

# %% [markdown]
# 6. Read the employees and titles tables into two separate DataFrames.

# %%
sql = """
    SELECT * from employees
"""
url = get_db_url("employees")

employees_df = pd.read_sql(sql, url)
employees_df.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
sql = """
    SELECT * from titles
"""
url = get_db_url("employees")

titles_df = pd.read_sql(sql, url)
titles_df.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %% [markdown]
# 7. How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
employees_df.shape
# Out:
# (300024, 6)

# %%
titles_df.shape
# Out:
# (443308, 4)

# %% [markdown]
# 8. Display the summary statistics for each DataFrame.

# %%
employees_df.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
titles_df.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %% [markdown]
# 9. How many unique titles are in the titles DataFrame?

# %%
len(titles_df.title.unique())
# Out:
# 7

# %% [markdown]
# 10. What is the oldest date in the to_date column?

# %%
titles_df.to_date.sort_values().head(1)
# Out:
# 16064    1985-03-01
# Name: to_date, dtype: object

# %% [markdown]
# 11. What is the most recent date in the to_date column?

# %%
sql = """
    SELECT * from titles
    where to_date < now()
"""
url = get_db_url("employees")

previous_titles = pd.read_sql(sql, url)
previous_titles.head()
# Out:
#    emp_no               title   from_date     to_date
# 0   10004            Engineer  1986-12-01  1995-12-01
# 1   10005               Staff  1989-09-12  1996-09-12
# 2   10007               Staff  1989-02-10  1996-02-11
# 3   10008  Assistant Engineer  1998-03-11  2000-07-31
# 4   10009  Assistant Engineer  1985-02-18  1990-02-18

# %%
# previous_titles[previous_titles.to_date == previous_titles.to_date.max()]
print(previous_titles.to_date.max())
# Out:
# 2002-08-01

# %% [markdown]
# ### Exercises II

# %% [markdown]
# 1. Copy the users and roles DataFrames from the examples above.

# %%
users = employees_df
users.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
roles = titles_df
roles.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %% [markdown]
# 2. What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, how='right', indicator=True)
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date _merge
# 0       Senior Engineer  1986-06-26  9999-01-01   both
# 1                 Staff  1996-08-03  9999-01-01   both
# 2       Senior Engineer  1995-12-03  9999-01-01   both
# 3              Engineer  1986-12-01  1995-12-01   both
# 4       Senior Engineer  1995-12-01  9999-01-01   both
# ...                 ...         ...         ...    ...
# 443303         Engineer  1987-08-30  1992-08-29   both
# 443304  Senior Engineer  1992-08-29  9999-01-01   both
# 443305     Senior Staff  1998-12-27  9999-01-01   both
# 443306            Staff  1993-12-27  1998-12-27   both
# 443307         Engineer  1997-11-30  9999-01-01   both
#
# [443308 rows x 10 columns]

# %% [markdown]
# 3. What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, how='outer')
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# 2       Senior Engineer  1995-12-03  9999-01-01
# 3              Engineer  1986-12-01  1995-12-01
# 4       Senior Engineer  1995-12-01  9999-01-01
# ...                 ...         ...         ...
# 443303         Engineer  1987-08-30  1992-08-29
# 443304  Senior Engineer  1992-08-29  9999-01-01
# 443305     Senior Staff  1998-12-27  9999-01-01
# 443306            Staff  1993-12-27  1998-12-27
# 443307         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 9 columns]

# %% [markdown]
# 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
users2 = users.drop(columns='emp_no')
roles2 = roles.drop(columns='emp_no')

# %%
# users2.merge(roles2)

# %% [markdown]
# 5. Load the mpg dataset from PyDataset.

# %%
from pydataset import data

# %%
mpg = data('mpg')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %% [markdown]
# 6. Output and read the documentation for the mpg dataset.

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# 7. How many rows and columns are in the dataset?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# 8. Check out your column names and perform any cleanup you may want on them.

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
mpg.rename(columns = {'cty' : 'city', 'hwy' : 'highway'}, inplace=True)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %% [markdown]
# 9. Display the summary statistics for the dataset.

# %%
mpg.describe()
# Out:
#             displ         year         cyl        city     highway
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# 10. How many different manufacturers are there?

# %%
len(mpg.groupby('manufacturer'))
# Out:
# 15

# %% [markdown]
# 11. How many different models are there?

# %%
len(mpg.groupby('model'))
# Out:
# 38

# %%
mpg.model.value_counts()
# Out:
# caravan 2wd               11
# ram 1500 pickup 4wd       10
# mustang                    9
# jetta                      9
# dakota pickup 4wd          9
# civic                      9
# impreza awd                8
# a4 quattro                 8
# grand cherokee 4wd         8
# toyota tacoma 4wd          7
# durango 4wd                7
# f150 pickup 4wd            7
# camry                      7
# tiburon                    7
# camry solara               7
# a4                         7
# passat                     7
# sonata                     7
# forester awd               6
# altima                     6
# new beetle                 6
# 4runner 4wd                6
# explorer 4wd               6
# gti                        5
# malibu                     5
# corolla                    5
# grand prix                 5
# c1500 suburban 2wd         5
# corvette                   5
# k1500 tahoe 4wd            4
# pathfinder 4wd             4
# range rover                4
# mountaineer 4wd            4
# navigator 2wd              3
# expedition 2wd             3
# maxima                     3
# a6 quattro                 3
# land cruiser wagon 4wd     2
# Name: model, dtype: int64

# %% [markdown]
# 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.highway - mpg.city
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_difference
# 1  compact                  11
# 2  compact                   8
# 3  compact                  11
# 4  compact                   9
# 5  compact                  10

# %% [markdown]
# 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.highway + mpg.city) / 2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_difference  average_mileage
# 1  compact                  11             23.5
# 2  compact                   8             25.0
# 3  compact                  11             25.5
# 4  compact                   9             25.5
# 5  compact                  10             21.0

# %% [markdown]
# 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg['is_automatic'] = np.where(mpg.trans.str.startswith('a'), True, False)
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_difference  average_mileage  is_automatic
# 1  compact                  11             23.5          True
# 2  compact                   8             25.0         False
# 3  compact                  11             25.5         False
# 4  compact                   9             25.5          True
# 5  compact                  10             21.0          True

# %% [markdown]
# 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg.groupby('manufacturer').average_mileage.agg('mean').sort_values().tail(1)
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %% [markdown]
# 16. Do automatic or manual cars have better miles per gallon?

# %%
b = mpg.groupby('is_automatic').average_mileage.agg('mean')
b
# Out:
# is_automatic
# False    22.227273
# True     19.130573
# Name: average_mileage, dtype: float64

# %% [markdown]
# ### Exercises III

# %% [markdown]
# 1. Use your get_db_url function to help you explore the data from the chipotle database.

# %%
sql = """
    SELECT * from orders
"""
url = get_db_url("chipotle")

ch = pd.read_sql(sql, url)
ch
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# 0                                                                                   nan
# 1                                                                          [Clementine]
# 2                                                                               [Apple]
# 3                                                                                   nan
# 4            [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# ...                                                                                 ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4618               [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese, Lettuce, Guacamole]]
# 4619         [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Guacamole, Lettuce]]
# 4620                                 [Fresh Tomato Salsa, [Fajita Vegetables, Lettuce]]
# 4621                    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto Beans, Lettuce]]
#
#      item_price
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
# ...         ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
#
# [4622 rows x 6 columns]

# %%
ch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  4622 non-null   object
#  5   item_price          4622 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 216.8+ KB

# %%
ch['item_price'] = ch.item_price.str.replace('$', '').astype(float)
# Out:
# <ipython-input-42-ed0ca99ec9d4>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   ch['item_price'] = ch.item_price.str.replace('$', '').astype(float)

# %%
ch.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#    item_price
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98

# %% [markdown]
# 2. What is the total price for each order?

# %%
ch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  4622 non-null   object
#  5   item_price          4622 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 216.8+ KB

# %%
ch.groupby('order_id').item_price.agg(sum)
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %% [markdown]
# 3. What are the most popular 3 items?

# %%
ch.groupby('item_name').quantity.agg('sum').sort_values(ascending=False).head(3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %%
ch.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#    item_price
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98

# %% [markdown]
# 4. Which item has produced the most revenue?

# %%
# ch.pivot_table(index='item_name', )
ch.groupby('item_name').item_price.agg('sum').sort_values(ascending=False).head(1)
# Out:
# item_name
# Chicken Bowl    7342.73
# Name: item_price, dtype: float64

# %% [markdown]
# 5. Join the employees and titles DataFrames together.

# %%
emp_titles = employees_df.merge(titles_df)
emp_titles.head(10)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date  \
# 0   10001  1953-09-02     Georgi    Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel     Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto    Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian    Koblick      M  1986-12-01
# 4   10004  1954-05-01  Chirstian    Koblick      M  1986-12-01
# 5   10005  1955-01-21    Kyoichi   Maliniak      M  1989-09-12
# 6   10005  1955-01-21    Kyoichi   Maliniak      M  1989-09-12
# 7   10006  1953-04-20     Anneke    Preusig      F  1989-06-02
# 8   10007  1957-05-23    Tzvetan  Zielinski      F  1989-02-10
# 9   10007  1957-05-23    Tzvetan  Zielinski      F  1989-02-10
#
#              title   from_date     to_date
# 0  Senior Engineer  1986-06-26  9999-01-01
# 1            Staff  1996-08-03  9999-01-01
# 2  Senior Engineer  1995-12-03  9999-01-01
# 3         Engineer  1986-12-01  1995-12-01
# 4  Senior Engineer  1995-12-01  9999-01-01
# 5     Senior Staff  1996-09-12  9999-01-01
# 6            Staff  1989-09-12  1996-09-12
# 7  Senior Engineer  1990-08-05  9999-01-01
# 8     Senior Staff  1996-02-11  9999-01-01
# 9            Staff  1989-02-10  1996-02-11

# %%
emp_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443308 entries, 0 to 443307
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      443308 non-null  int64
#  1   birth_date  443308 non-null  object
#  2   first_name  443308 non-null  object
#  3   last_name   443308 non-null  object
#  4   gender      443308 non-null  object
#  5   hire_date   443308 non-null  object
#  6   title       443308 non-null  object
#  7   from_date   443308 non-null  object
#  8   to_date     443308 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 33.8+ MB

# %% [markdown]
# 6. For each title, find the hire date of the employee that was hired most recently with that title.

# %%
emp_titles['hire_date'] = pd.to_datetime(emp_titles.hire_date)
emp_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443308 entries, 0 to 443307
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      443308 non-null  int64
#  1   birth_date  443308 non-null  object
#  2   first_name  443308 non-null  object
#  3   last_name   443308 non-null  object
#  4   gender      443308 non-null  object
#  5   hire_date   443308 non-null  datetime64[ns]
#  6   title       443308 non-null  object
#  7   from_date   443308 non-null  object
#  8   to_date     443308 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 33.8+ MB

# %%
emp_titles.groupby('title').hire_date.max()
# Out:
# title
# Assistant Engineer   1999-12-24
# Engineer             2000-01-28
# Manager              1992-02-05
# Senior Engineer      2000-01-01
# Senior Staff         2000-01-13
# Staff                2000-01-12
# Technique Leader     1999-12-31
# Name: hire_date, dtype: datetime64[ns]

# %% [markdown]
# 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
sql = """
    SELECT * from employees
    join dept_emp using(emp_no)
    join departments using(dept_no);
"""
url = get_db_url("employees")

emps = pd.read_sql(sql, url)
emps.head(10)
# Out:
#   dept_no  emp_no  birth_date   first_name    last_name gender   hire_date  \
# 0    d009   10011  1953-11-07         Mary        Sluis      F  1990-01-22
# 1    d009   10038  1960-07-20         Huan        Lortz      M  1989-09-20
# 2    d009   10049  1961-04-24        Basil       Tramer      F  1992-05-04
# 3    d009   10060  1961-10-15     Breannda  Billingsley      M  1987-11-02
# 4    d009   10088  1954-02-25     Jungsoon     Syrzycki      F  1988-09-02
# 5    d009   10098  1961-09-23  Sreekrishna    Servieres      F  1985-05-13
# 6    d009   10112  1963-08-13     Yuichiro        Swick      F  1985-10-08
# 7    d009   10115  1964-12-25      Chikara     Rissland      M  1986-01-23
# 8    d009   10126  1954-08-07       Kayoko     Valtorta      M  1985-09-08
# 9    d009   10128  1958-02-15      Babette        Lamba      F  1988-06-06
#
#     from_date     to_date         dept_name
# 0  1990-01-22  1996-11-09  Customer Service
# 1  1989-09-20  9999-01-01  Customer Service
# 2  1992-05-04  9999-01-01  Customer Service
# 3  1992-11-11  9999-01-01  Customer Service
# 4  1992-03-21  9999-01-01  Customer Service
# 5  1989-06-29  1992-12-11  Customer Service
# 6  1998-05-01  9999-01-01  Customer Service
# 7  1988-03-03  1992-05-24  Customer Service
# 8  1985-09-08  9999-01-01  Customer Service
# 9  1988-06-06  9999-01-01  Customer Service

# %%
emps2 = emps.merge(titles_df)
emps2.head(10)
# Out:
#   dept_no  emp_no  birth_date first_name       last_name gender   hire_date  \
# 0    d009   10011  1953-11-07       Mary           Sluis      F  1990-01-22
# 1    d009   10112  1963-08-13   Yuichiro           Swick      F  1985-10-08
# 2    d009   10115  1964-12-25    Chikara        Rissland      M  1986-01-23
# 3    d009   10154  1957-01-17    Abdulah       Thibadeau      F  1990-12-12
# 4    d009   10183  1954-10-17  Mechthild        Bonifati      M  1996-08-11
# 5    d009   10184  1957-05-22    Mihalis          Lowrie      M  1987-10-29
# 6    d009   10213  1964-05-24    Jackson          Kakkad      M  1992-11-06
# 7    d009   10225  1957-02-13     Kellie          Chinen      F  1986-06-19
# 8    d009   10231  1963-07-21    Shaowen         Desikan      F  1996-04-13
# 9    d009   10286  1952-05-14     Saddek  Gopalakrishnan      F  1988-03-21
#
#     from_date     to_date         dept_name  title
# 0  1990-01-22  1996-11-09  Customer Service  Staff
# 1  1998-05-01  9999-01-01  Customer Service  Staff
# 2  1988-03-03  1992-05-24  Customer Service  Staff
# 3  1996-10-23  9999-01-01  Customer Service  Staff
# 4  1996-08-11  9999-01-01  Customer Service  Staff
# 5  1997-12-26  9999-01-01  Customer Service  Staff
# 6  1994-10-06  9999-01-01  Customer Service  Staff
# 7  1995-12-14  9999-01-01  Customer Service  Staff
# 8  1998-09-09  9999-01-01  Customer Service  Staff
# 9  1994-12-24  1999-01-24  Customer Service  Staff

# %%
pd.crosstab(emps2.dept_name, emps2.title)
# Out:
# title               Assistant Engineer  Engineer  Senior Engineer  \
# dept_name
# Customer Service                     1         0                2
# Development                       2666     18311            13331
# Finance                              0         0                0
# Human Resources                      0         0                0
# Marketing                            0         0                0
# Production                        2044     14733            10748
# Quality Management                 531      3682             2745
# Research                             0         5                3
# Sales                                0         0                0
#
# title               Senior Staff  Staff  Technique Leader
# dept_name
# Customer Service            3032   4602                 0
# Development                    1      1              6802
# Finance                     2893   4434                 0
# Human Resources             2909   4704                 0
# Marketing                   2969   4551                 0
# Production                     0      1              5447
# Quality Management             0      0              1321
# Research                    2942   4602                 0
# Sales                       9074  13813                 0
